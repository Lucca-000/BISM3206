# %%
# dictionary for future reference of DataFrame

import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
'''
# 1) Import CSV (or any format) into a DataFrame (must be in the folder to import)
df = pd.read_csv("your_file.csv")

# 2) Quick checks
df.head()        # first 5 rows
df.tail()        # last 5 rows
df.shape         # (rows, columns)
df.columns       # column names
df.dtypes        # data types
df.info()        # summary incl. non-null counts
df.describe()    # numeric summary stats
df.describe(include="all")  # includes non-numeric too

# 3) Common cleaning / prep
df.isna().sum()      # missing values per column
df.dropna()          # remove rows with missing values
df.fillna(0)         # fill missing values
df["col"].unique()   # unique values in a column
df["col"].value_counts()  # frequency table

# 4) Filtering and selecting
df["col"]                    # single column
df[["col1", "col2"]]         # multiple columns
df[df["col"] > 100]          # row filter
df.loc[0:4, ["col1"]]        # label-based select
df.iloc[0:5, 0:2]            # position-based select

# 5) Sorting and grouping
df.sort_values("col", ascending=False)
df.groupby("category")["value"].mean()
'''
# Out:
# '\n# 1) Import CSV (or any format) into a DataFrame (must be in the folder to import)\ndf = pd.read_csv("your_file.csv")\n\n# 2) Quick checks\ndf.head()        # first 5 rows\ndf.tail()        # last 5 rows\ndf.shape         # (rows, columns)\ndf.columns       # column names\ndf.dtypes        # data types\ndf.info()        # summary incl. non-null counts\ndf.describe()    # numeric summary stats\ndf.describe(include="all")  # includes non-numeric too\n\n# 3) Common cleaning / prep\ndf.isna().sum()      # missing values per column\ndf.dropna()          # remove rows with missing values\ndf.fillna(0)         # fill missing values\ndf["col"].unique()   # unique values in a column\ndf["col"].value_counts()  # frequency table\n\n# 4) Filtering and selecting\ndf["col"]                    # single column\ndf[["col1", "col2"]]         # multiple columns\ndf[df["col"] > 100]          # row filter\ndf.loc[0:4, ["col1"]]        # label-based select\ndf.iloc[0:5, 0:2]            # position-based
# ...

# %%
df=pd.read_excel('M1.1 Data.XLSX')
cleaned=df.dropna()
print(cleaned)
df.dtypes
# Out:
#      Gender  Age Payment Method  Churn  LastTransaction
# 0      male   64    credit card  loyal               98
# 1      male   35         cheque  churn              118
# 2    female   25    credit card  loyal              107
# 4      male   39    credit card  loyal               90
# 5    female   28         cheque  churn              189
# ..      ...  ...            ...    ...              ...
# 990    male   19    credit card  loyal               92
# 991  female   29    credit card  loyal               33
# 992    male   84    credit card  loyal              124
# 994    male   19    credit card  loyal               49
# 995  female   24    credit card  loyal               25
#
# [900 rows x 5 columns]
# c:\Users\lucca\OneDrive\Documents\BBUS\BISM\BISM3206\BISM3206\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Gender               str
# Age                int64
# ...

# %%
state_data=pd.read_excel('combined_state.xlsx',header=None,names=['Entries','State','Blah','Blah'])
summary= state_data.describe()
state_data = state_data.dropna()
print(type(state_data))
print(type)
# Out:
# <class 'pandas.DataFrame'>
# Empty DataFrame
# Columns: [Entries, State, Blah, Blah.1]
# Index: []
